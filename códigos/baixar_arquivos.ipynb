# %% [markdown]
# https://dadosabertos.camara.leg.br/swagger/api.html#staticfile

# %%
import pandas as pd

# %% [markdown]
# ### **Classificação temática das proposições**
# Nestes arquivos, separados por ano de apresentação das proposições, cada registro corresponde a uma área temática na qual uma proposição foi *classificada* pelo Centro de Documentação e Informação da Câmara. Estão presentes os identificadores mínimos de proposições e de temas. A lista dos temas existentes e seus códigos pode ser obtida na API do Dados Abertos em JSON e XML.

# %%
# http://dadosabertos.camara.leg.br/arquivos/proposicoesTemas/{formato}/proposicoesTemas-{ano}.{formato}
temas_proposicoes_2021 = pd.read_csv(r"http://dadosabertos.camara.leg.br/arquivos/proposicoesTemas/csv/proposicoesTemas-2021.csv", sep=";", encoding="utf-8", error_bad_lines=False)

# %%
temas_proposicoes_2021
# Out:
#                                            uriProposicao  ... relevancia
# 0      https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 1      https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 2      https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 3      https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 4      https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# ...                                                  ...  ...        ...
# 14048  https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 14049  https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 14050  https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 14051  https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
# 14052  https://dadosabertos.camara.leg.br/api/v2/prop...  ...          0
#
# [14053 rows x 7 columns]

# %% [markdown]
# ## **Proposições por ano de apresentação**
# Arquivos em que cada registro contém dados sobre uma proposição apresentada à Câmara dos Deputados para deliberação, como identificador universal (URI), sigla, número, ano, ementa, temas e keywords, informações sobre a tramitação mais recente, proposições a que se relacionam, etc.

# %%
## Proposições por ano de apresentação
# http://dadosabertos.camara.leg.br/arquivos/proposicoes/{formato}/proposicoes-{ano}.{formato}
proposicoes_2021 = pd.read_csv(r"http://dadosabertos.camara.leg.br/arquivos/proposicoes/csv/proposicoes-2021.csv", sep=";", encoding="utf-8", error_bad_lines=False)
proposicoes_2021
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             id  ...                                   ultimoStatus_url
# 0       459323  ...                                                NaN
# 1       498347  ...                                                NaN
# 2       540979  ...                                                NaN
# 3       946514  ...                                                NaN
# 4      2184458  ...  http://www.camara.gov.br/proposicoesWeb/prop_m...
# ...        ...  ...                                                ...
# 37945  2311809  ...  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 37946  2311810  ...  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 37947  2311811  ...  http://www.camara.gov.br/proposicoesWeb/prop_m...
# ...

# %%
#http://dadosabertos.camara.leg.br/arquivos/votacoes/{formato}/votacoes-{ano}.{formato}, em que:
votacoes_2021 = pd.read_csv(r"http://dadosabertos.camara.leg.br/arquivos/votacoes/csv/votacoes-2021.csv", sep=";", encoding="utf-8", error_bad_lines=False)
votacoes_2021
# Out:
#               id  ...         ultimaApresentacaoProposicao_uriProposicao
# 0      2268563-5  ...                                                NaN
# 1      2268563-7  ...                                                NaN
# 2      2269049-8  ...                                                NaN
# 3      2269480-8  ...                                                NaN
# 4     2268644-29  ...  https://dadosabertos.camara.leg.br/api/v2/prop...
# ...          ...  ...                                                ...
# 9606  614512-195  ...  https://dadosabertos.camara.leg.br/api/v2/prop...
# 9607  2285694-50  ...                                                NaN
# 9608  2285694-55  ...                                                NaN
# 9609  2285694-58  ...                                                NaN
# 9610  2285694-60  ...                                                NaN
#
# [9611 rows x 20 columns]

# %% [markdown]
# # Votações
# ## Votações realizadas a cada ano
# Identificadores e informações sobre as votações das comissões e do Plenário da Câmara, por ano em que tenham ocorrido. Para cada votação, há a data informada, data e hora de registro nos sistemas da Câmara, descrição do resultado da votação, identificadores do Órgão e do Evento, um indicador que diz se a votação resultou em aprovação ou não da proposição votada, um placar resumido e, se disponíveis, dados sobre a abertura de votação e a apresentação de proposição que tenham ocorrido logo antes da votação.

# %%
#http://dadosabertos.camara.leg.br/arquivos/votacoes/{formato}/votacoes-{ano}.{formato}, em que:
votacoes_2021 = pd.read_csv(r"http://dadosabertos.camara.leg.br/arquivos/votacoes/csv/votacoes-2021.csv", sep=";", encoding="utf-8", error_bad_lines=False)
votacoes_2021

# %%
votacoesObjetos_2021 = pd.read_csv(r"http://dadosabertos.camara.leg.br/arquivos/votacoesObjetos/csv/votacoesObjetos-2021.csv", sep=";", encoding="utf-8", error_bad_lines=False)

# %%
votacoesObjetos_2021
# Out:
#         idVotacao  ...                                  proposicao_titulo
# 0       2268563-5  ...                                         OBJ 1/2021
# 1       2268563-7  ...                                         OBJ 1/2021
# 2      2265124-34  ...                                        REQ 79/2021
# 3      2265124-34  ...                              PRLP 1 => PLP 19/2019
# 4      2265124-34  ...                               EMP 1 => PLP 19/2019
# ...           ...  ...                                                ...
# 51834  614512-195  ...  PRLP 1 => PL 4157/2019 (Nº Anterior: PL 7512/2...
# 51835  614512-195  ...  PSS 1 CCJC => PL 4157/2019 (Nº Anterior: PL 75...
# 51836  946514-112  ...  PRL 1 CMADS => PL 2419/2021 (Nº Anterior: pl 3...
# 51837  946514-112  ...  PAR 1 CMADS => PL 2419/2021 (Nº Anterior: pl 3...
# 51838  946514-112  ...  PSS 1 CMADS => PL 2419/2021 (Nº Anterior: pl 3...
#
# [51839 rows x 12 columns]
