# %% [markdown]
# ### Código para exploração inicial das bases de votações da Câmara dos Deputados

# %%
import pandas as pd

# %%
votos = pd.read_csv(r'votacoesVotos-2021.csv', sep=';')
proposicoes = pd.read_csv(r'proposicoes-2021.csv', sep=';')
orientacoes = pd.read_csv(r'votacoesOrientacoes-2021.csv', sep=';')
# Out:
# C:\Users\bianc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
votos.head(10)
# Out:
#    idVotacao                                         uriVotacao  \
# 0  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 1  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 2  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 3  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 4  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 5  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 6  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 7  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 8  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
# 9  14666-138  https://dadosabertos.camara.leg.br/api/v2/vota...
#
#           dataHoraVoto voto  deputado_id  \
# 0  2021-08-04T11:39:19  Sim       204545
# 1  2021-08-04T11:39:19  Sim        73696
# 2  2021-08-04T11:39:19  Sim       160512
# 3  2021-08-04T11:39:19  Sim       204374
# 4  2021-08-04T11:39:19  Sim       141513
# ...

# %%
proposicoes.head(10)
# Out:
#         id                                                uri siglaTipo  \
# 0   459323  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 1   498347  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 2   540979  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 3   946514  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 4  2184458  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 5  2268420  https://dadosabertos.camara.leg.br/api/v2/prop...       EMC
# 6  2268421  https://dadosabertos.camara.leg.br/api/v2/prop...       RIC
# 7  2268422  https://dadosabertos.camara.leg.br/api/v2/prop...       RIC
# 8  2268423  https://dadosabertos.camara.leg.br/api/v2/prop...       RIC
# 9  2268424  https://dadosabertos.camara.leg.br/api/v2/prop...       MPV
#
#    numero   ano  codTipo               descricaoTipo  \
# 0    1558  2021      139              Projeto de Lei
# 1     886  2021      139              Projeto de Lei
# ...

# %%
orientacoes.head(10)
# Out:
#     idVotacao                                         uriVotacao siglaOrgao  \
# 0  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 1  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 2  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 3  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 4  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 5  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 6  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 7  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 8  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
# 9  2226269-18  https://dadosabertos.camara.leg.br/api/v2/vota...       PLEN
#
#                                            descricao siglaBancada  \
# ...
